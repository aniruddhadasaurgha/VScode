# %%
print("What is the type of above given database- \n 1) Relational Dtabase \n 2)Non_Relational Database")
answer = int(input("Enter your guess here..."))
if answer == 2:
  print("You guessed it right!")
else:
  print("Unfortunately your guess was wrong.")
print("\n Plaese tell your mentor why you guessed this?")
# Out:
# What is the type of above given database-
#  1) Relational Dtabase
#  2)Non_Relational Database
# Enter your guess here...1
# Unfortunately your guess was wrong.
#
#  Plaese tell your mentor why you guessed this?

# %%
from google.colab import files
file = files.upload()

import sqlite3
database = 'database.sqlite'
conn = sqlite3.connect(database)
print('Opened data successfully')

import pandas as pd
tables = pd.read_sql("""
SELECT *
FROM sqlite_master
WHERE type='table';
""", conn)

tables
