# %%
file = open("Sample_File.txt", "r")
print(file.read())
file = open("Sample_File.txt", "w")
file = file.write("Hi I am Aniruddha Das Aurgha and my age is 15.")
file = open("Sample_File.txt", "a")
print(file.write("My favourite subject is Mathematics."))
file.close()
# Out:
# Hi I am Aniruddha Das Aurgha and my age is 15.My favourite subject is Mathematics.
# 36
