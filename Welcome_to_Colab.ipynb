# %%
file=open('Codingal.txt')

print(file.read())

file.close()
# Out:
# ﻿Codingal is on a mission to inspire school kids to fall in love with coding.
# Coding helps develop logical thinking and problem-solving skills.
# Coding jobs are the future.
# They already constitute more than 60% of all the jobs in Science, Technology, Engineering, and Math.
# While still in school, those who start young will be ahead of everyone by the time they get into college.
# They will be creators of the future.
# Do you want to join us too?

# %%
# File Handling Operations

# Read Mode

file_read = open('Codingal.txt', 'r')

print("File in Read Mode -")

print(file_read.read())

file_read.close()

# Write Mode

file_write = open('Codingal.txt', 'w')

file_write.write(" File in write mode ... ")

file_write.write("Hi! I am Aniruddha. I am 15 yr. old ")

file_write.close()

# Append Mode

file_append = open('Codingal.txt', 'a')

file_append.write("\n File in append mode ... ")

file_append.write("Hi! I am Aniruddha. I am 15 yr. old ")

file_append.close()
# Out:
# File in Read Mode -
#  File in write mode ... Hi! I am Aniruddha. I am 15 yr. old
#  File in append mode ... Hi! I am Aniruddha. I am 15 yr. old

# %%
# Program to count number of lines in a file

# Opening a file

file = open("Codingal.txt", "r")

Counter = 0

# Reading from file

Content = file.read()

# Splitting content into lines and storing them in a list

Colist = Content.split("\n")

for i in Colist:

 if i:

  Counter += 1

print("This is the number of lines in the file")

print(Counter)
# Out:
# This is the number of lines in the file
# 2
